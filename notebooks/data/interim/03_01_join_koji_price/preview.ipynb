# %% [markdown]
# # 03_01_join_koji_price 検証ノート
#
# 公示価格GeoJSONから生成した `train.parquet` / `test.parquet` をざっと確認する。`pd.options.display.max_rows` を増やし、先頭20行を転置表示して列ごとのスケールを把握する。

# %%
from pathlib import Path

import pandas as pd
from IPython.display import display

pd.options.display.max_rows = 400


def find_project_root(start: Path) -> Path:
    candidate = start.resolve()
    for path in [candidate, *candidate.parents]:
        if (path / "data").is_dir() and (path / "src").is_dir():
            return path
    raise RuntimeError(f"Project root not found from {start}")


try:
    PROJECT_ROOT = find_project_root(Path(__file__))
except NameError:
    PROJECT_ROOT = find_project_root(Path.cwd())

ARTIFACTS = [
    ("train", PROJECT_ROOT / "data" / "interim" / "03_01_join_koji_price" / "train.parquet"),
    ("test", PROJECT_ROOT / "data" / "interim" / "03_01_join_koji_price" / "test.parquet"),
]
PRICE_COLUMNS = [
    "2023_koji_price",
    "2022_koji_price",
    "2021_koji_price",
    "2020_koji_price",
    "2019_koji_price",
    "2018_koji_price",
]
GROWTH_COLUMNS = ["koji_price_growth_2023_vs_2022"]

# %%
for label, artifact_path in ARTIFACTS:
    rel_path = artifact_path.relative_to(PROJECT_ROOT)
    df = pd.read_parquet(artifact_path)

    print(f"=== {label} ===")
    print(f"path: {rel_path}")
    print(f"shape: {df.shape}")
    print(df.dtypes)
    display(df.head(20).transpose())
    display(df[PRICE_COLUMNS].describe(percentiles=[0.25, 0.5, 0.75]).transpose())
    display(df[GROWTH_COLUMNS].describe(percentiles=[0.25, 0.5, 0.75]).transpose())
    print(df["bukken_type_label"].value_counts(dropna=False).to_frame("count"))
    print("\n")
# Out:
# === train ===
# path: data/interim/03_01_join_koji_price/train.parquet
# shape: (363924, 23)
# data_id                             int64
# bukken_type                         Int64
# bukken_type_label          string[python]
# 2023_koji_price                   Float64
# 2022_koji_price                   Float64
# 2021_koji_price                   Float64
# 2020_koji_price                   Float64
# 2019_koji_price                   Float64
# 2018_koji_price                   Float64
# 2023_koji_usage_code       string[python]
# 2022_koji_usage_code       string[python]
# 2021_koji_usage_code       string[python]
# 2020_koji_usage_code       string[python]
# 2019_koji_usage_code       string[python]
# 2018_koji_usage_code       string[python]
# 2023_koji_distance_km             Float64
# 2022_koji_distance_km             Float64
# 2021_koji_distance_km             Float64
# 2020_koji_distance_km             Float64
# 2019_koji_distance_km             Float64
# 2018_koji_distance_km             Float64
# koji_usage_status          string[python]
# koji_building_structure    string[python]
# dtype: object
#                                0         1         2         3         4   \
# data_id                         0         1         2         3         4
# bukken_type                  1202      1202      1202      1202      1302
# bukken_type_label          kodate    kodate    kodate    kodate   mansion
# 2023_koji_price           41600.0   63700.0   14700.0   71900.0   71900.0
# 2022_koji_price           41500.0   63400.0   14600.0   71500.0   71500.0
# 2021_koji_price           41500.0   63200.0   14500.0   71500.0   71500.0
# 2020_koji_price           41600.0   63200.0   63200.0   72300.0   72300.0
# 2019_koji_price           41600.0   62900.0   62900.0   72300.0   72300.0
# 2018_koji_price           41700.0   62700.0   62700.0   73000.0   73000.0
# 2023_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2022_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2021_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2020_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2019_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2018_koji_usage_code          1低専       1低専       1低専       1中専       1中専
# 2023_koji_distance_km    0.565868  0.282589  0.623686  0.398846  0.334042
# 2022_koji_distance_km    0.565864  0.282589  0.623689  0.398847  0.334043
# 2021_koji_distance_km    0.565864  0.282589  0.623689  0.398847  0.334043
# 2020_koji_distance_km    0.565864  0.282589  0.672825  0.398847  0.334043
# 2019_koji_distance_km    0.565875  0.282599   0.67284  0.398847  0.334046
# 2018_koji_distance_km    0.565875  0.282599   0.67284  0.398847  0.334046
# koji_usage_status              住宅        住宅        農地        住宅        住宅
# koji_building_structure         W         W       その他         W         W
#
#                                5         6         7         8         9   \
# data_id                         5         6         7         8         9
# bukken_type                  1202      1202      1202      1202      1202
# bukken_type_label          kodate    kodate    kodate    kodate    kodate
# 2023_koji_price           64000.0   62200.0   36100.0   72900.0   72900.0
# 2022_koji_price           63600.0   61800.0   36700.0   72000.0   72000.0
# 2021_koji_price           63600.0   61800.0   37600.0   72000.0   72000.0
# 2020_koji_price           64300.0   62500.0   38600.0   72800.0   72800.0
# 2019_koji_price           64300.0   63000.0   39300.0   72800.0   72800.0
# 2018_koji_price           64500.0   63600.0   40100.0   73400.0   73400.0
# 2023_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2022_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2021_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2020_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2019_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2018_koji_usage_code          1中専       1住居       1中専       1中専       1中専
# 2023_koji_distance_km    0.169858  0.156263  0.685516  0.579868  0.333889
# 2022_koji_distance_km    0.169857  0.156263  0.685517  0.579867  0.333888
# 2021_koji_distance_km    0.169857  0.156263  0.685517  0.579867  0.333888
# 2020_koji_distance_km    0.169857  0.156263  0.685517  0.579867  0.333888
# 2019_koji_distance_km    0.169863  0.156262  0.685526  0.579861  0.333885
# 2018_koji_distance_km    0.169863  0.156262  0.685526  0.579861  0.333885
# koji_usage_status              住宅        住宅        住宅        住宅        住宅
# koji_building_structure         W         W         W         W         W
#
#                                10        11        12        13        14  \
# data_id                        10        11        12        13        14
# bukken_type                  1202      1202      1302      1202      1202
# bukken_type_label          kodate    kodate   mansion    kodate    kodate
# 2023_koji_price           72900.0   92100.0   90000.0  100000.0   72900.0
# 2022_koji_price           72000.0   91600.0   85200.0   99400.0   72000.0
# 2021_koji_price           72000.0   91600.0   83600.0   99400.0   72000.0
# 2020_koji_price           72800.0   93000.0   84000.0  101000.0   72800.0
# 2019_koji_price           72800.0   93000.0   83900.0  101000.0   72800.0
# 2018_koji_price           73400.0   94400.0   83700.0  101000.0   73400.0
# 2023_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2022_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2021_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2020_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2019_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2018_koji_usage_code          1中専       準住居        準工        近商       1中専
# 2023_koji_distance_km     0.29577  0.301883  0.306181   0.42179  0.029988
# 2022_koji_distance_km    0.295769  0.301886  0.306181  0.421786  0.029988
# 2021_koji_distance_km    0.295769  0.301886  0.306181  0.421786  0.029988
# 2020_koji_distance_km    0.295769  0.301886  0.306181  0.421786  0.029988
# 2019_koji_distance_km    0.295764  0.301875  0.306193  0.421793  0.029998
# 2018_koji_distance_km    0.295764  0.301875  0.306193  0.421793  0.029997
# koji_usage_status              住宅        店舗        住宅        店舗        住宅
# koji_building_structure         W        RC         W         W         W
#
#                                15        16        17        18        19
# data_id                        15        16        17        18        19
# bukken_type                  1202      1302      1302      1202      1202
# bukken_type_label          kodate   mansion   mansion    kodate    kodate
# 2023_koji_price           72900.0   72900.0   72900.0   26800.0  108000.0
# 2022_koji_price           72000.0   72000.0   72000.0   26100.0  107000.0
# 2021_koji_price           72000.0   72000.0   72000.0   25700.0  107000.0
# 2020_koji_price           72800.0   72800.0   72800.0   26000.0  109000.0
# 2019_koji_price           72800.0   72800.0   72800.0   26000.0  109000.0
# 2018_koji_price           73400.0   73400.0   73400.0   26000.0  109000.0
# 2023_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2022_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2021_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2020_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2019_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2018_koji_usage_code          1中専       1中専       1中専        工専       1中専
# 2023_koji_distance_km    0.041772  0.333553  0.333553  0.865152  0.492419
# 2022_koji_distance_km    0.041773  0.333552  0.333552  0.865153  0.492419
# 2021_koji_distance_km    0.041773  0.333552  0.333552  0.865153  0.492419
# 2020_koji_distance_km    0.041773  0.333552  0.333552  0.865153  0.492419
# 2019_koji_distance_km    0.041768  0.333541  0.333541  0.865146  0.492406
# 2018_koji_distance_km    0.041768  0.333541  0.333541  0.865146  0.492406
# koji_usage_status              住宅        住宅        住宅        倉庫        店舗
# koji_building_structure         W         W         W         S         S
#                     count           mean            std    min      25%  \
# 2023_koji_price  360162.0  313254.336021  564299.926344  570.0  79800.0
# 2022_koji_price  360167.0  301956.233161  541664.155377  600.0  78600.0
# 2021_koji_price  360171.0  298758.691441  565148.165746  630.0  78100.0
# 2020_koji_price  360160.0  301519.263036  582297.926975  660.0  78500.0
# 2019_koji_price  360157.0  282711.684501  528198.087515  690.0  78000.0
# 2018_koji_price  360171.0  266782.486763  476390.324285  720.0  77500.0
#
#                       50%       75%         max
# 2023_koji_price  157000.0  318000.0  22400000.0
# 2022_koji_price  153000.0  305000.0  22100000.0
# 2021_koji_price  152000.0  300000.0  39300000.0
# 2020_koji_price  152000.0  300000.0  42700000.0
# 2019_koji_price  150000.0  290000.0  42000000.0
# 2018_koji_price  148000.0  282000.0  40100000.0
#                           count      mean       std       min       25%  \
# 2023_koji_distance_km  360162.0  0.417959  0.372397  0.000027  0.202026
# 2022_koji_distance_km  360167.0  0.417703  0.371812  0.000027  0.202079
# 2021_koji_distance_km  360171.0  0.417764  0.372301  0.000027  0.202002
# 2020_koji_distance_km  360160.0  0.418129  0.373458  0.000027  0.202053
# 2019_koji_distance_km  360157.0  0.417939  0.373557  0.000028   0.20201
# 2018_koji_distance_km  360171.0  0.418224  0.374169  0.000028  0.202066
#
#                             50%       75%       max
# 2023_koji_distance_km  0.324335  0.495494  2.999553
# 2022_koji_distance_km  0.324255  0.494859  2.999556
# 2021_koji_distance_km  0.324095  0.494609  2.999556
# 2020_koji_distance_km  0.323957  0.494508  2.999556
# 2019_koji_distance_km  0.323752  0.494119  2.999549
# 2018_koji_distance_km  0.323882  0.494199  2.999549
#                        count unique  top   freq
# 2023_koji_usage_code  349387     12  1低専  83938
# 2022_koji_usage_code  349414     12  1低専  83794
# 2021_koji_usage_code  349394     12  1低専  83548
# 2020_koji_usage_code  349405     12  1低専  83666
# 2019_koji_usage_code  349406     12  1低専  83510
# 2018_koji_usage_code  349386     12  1低専  83399
#                     count
# bukken_type_label
# mansion            198614
# kodate             165310
#
#
# === test ===
# path: data/interim/03_01_join_koji_price/test.parquet
# shape: (112437, 23)
# data_id                    string[python]
# bukken_type                         Int64
# bukken_type_label          string[python]
# 2023_koji_price                   Float64
# 2022_koji_price                   Float64
# 2021_koji_price                   Float64
# 2020_koji_price                   Float64
# 2019_koji_price                   Float64
# 2018_koji_price                   Float64
# 2023_koji_usage_code       string[python]
# 2022_koji_usage_code       string[python]
# 2021_koji_usage_code       string[python]
# 2020_koji_usage_code       string[python]
# 2019_koji_usage_code       string[python]
# 2018_koji_usage_code       string[python]
# 2023_koji_distance_km             Float64
# 2022_koji_distance_km             Float64
# 2021_koji_distance_km             Float64
# 2020_koji_distance_km             Float64
# 2019_koji_distance_km             Float64
# 2018_koji_distance_km             Float64
# koji_usage_status          string[python]
# koji_building_structure    string[python]
# dtype: object
#                                0         1         2         3         4   \
# data_id                         0         1         2         3         4
# bukken_type                  1302      1202      1202      1202      1202
# bukken_type_label         mansion    kodate    kodate    kodate    kodate
# 2023_koji_price           69600.0   88000.0   56100.0   71900.0   41600.0
# 2022_koji_price           69200.0   86400.0   56300.0   71500.0   41500.0
# 2021_koji_price           69000.0   85600.0   56900.0   71500.0   41500.0
# 2020_koji_price           69000.0   85600.0   58000.0   72300.0   41600.0
# 2019_koji_price           68400.0   84100.0   59400.0   72300.0   41600.0
# 2018_koji_price           68000.0   82700.0   60000.0   73000.0   41700.0
# 2023_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2022_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2021_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2020_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2019_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2018_koji_usage_code          1住居       1低専       1低専       1中専       1低専
# 2023_koji_distance_km     0.21185  0.217077  0.109159  0.321384  0.396144
# 2022_koji_distance_km    0.211851  0.217077  0.109162  0.321384  0.396148
# 2021_koji_distance_km    0.211851  0.217077  0.109162  0.321384  0.396148
# 2020_koji_distance_km    0.211851  0.217077  0.109162  0.321384  0.396148
# 2019_koji_distance_km     0.21186  0.217082  0.109149  0.321379  0.396138
# 2018_koji_distance_km     0.21186  0.217082  0.109149  0.321379  0.396138
# koji_usage_status              住宅        住宅        住宅        住宅        住宅
# koji_building_structure        LS        LS         W         W         W
#
#                                5         6         7         8         9   \
# data_id                         5         6         7         8         9
# bukken_type                  1202      1202      1302      1202      1202
# bukken_type_label          kodate    kodate   mansion    kodate    kodate
# 2023_koji_price           67400.0   36100.0   41700.0   64000.0  100000.0
# 2022_koji_price           66900.0   36700.0   42400.0   63600.0   99400.0
# 2021_koji_price           66700.0   37600.0   43500.0   63600.0   99400.0
# 2020_koji_price           66700.0   38600.0   44700.0   64300.0  101000.0
# 2019_koji_price           66300.0   39300.0   45700.0   64300.0  101000.0
# 2018_koji_price           66000.0   40100.0   46700.0   64500.0  101000.0
# 2023_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2022_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2021_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2020_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2019_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2018_koji_usage_code          1低専       1中専       1住居       1中専        近商
# 2023_koji_distance_km    0.128275    1.0296  0.376624  0.644672  0.280919
# 2022_koji_distance_km    0.128276  1.029601  0.376623  0.644673  0.280916
# 2021_koji_distance_km    0.128276  1.029601  0.376623  0.644673  0.280916
# 2020_koji_distance_km    0.128276  1.029601  0.376623  0.644673  0.280916
# 2019_koji_distance_km    0.128282  1.029608  0.376662  0.644675  0.280919
# 2018_koji_distance_km    0.128282  1.029608  0.376662  0.644675  0.280919
# koji_usage_status              住宅        住宅        住宅        住宅        店舗
# koji_building_structure         W         W         W         W         W
#
#                                10        11        12        13        14  \
# data_id                        10        11        12        13        14
# bukken_type                  1202      1202      1202      1202      1202
# bukken_type_label          kodate    kodate    kodate    kodate    kodate
# 2023_koji_price           72900.0   72900.0   55000.0   17600.0   23000.0
# 2022_koji_price           72000.0   72000.0   55000.0   18300.0   23500.0
# 2021_koji_price           72000.0   72000.0   55100.0   19000.0   23700.0
# 2020_koji_price           72800.0   72800.0   55200.0   19600.0   23900.0
# 2019_koji_price           72800.0   72800.0   55300.0   20000.0   24100.0
# 2018_koji_price           73400.0   73400.0   55400.0   20300.0   24200.0
# 2023_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2022_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2021_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2020_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2019_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2018_koji_usage_code          1中専       1中専      <NA>        近商      <NA>
# 2023_koji_distance_km     0.26669  0.489273   0.08621  0.275938  1.938097
# 2022_koji_distance_km    0.266689  0.489272  0.086213  0.275938  1.938099
# 2021_koji_distance_km    0.266689  0.489272  0.086213  0.275938  1.938099
# 2020_koji_distance_km    0.266689  0.489272  0.086213  0.277524  1.938099
# 2019_koji_distance_km    0.266678  0.489265  0.086198  0.277516   1.93809
# 2018_koji_distance_km    0.266678  0.489265  0.086198  0.277516   1.93809
# koji_usage_status              住宅        住宅        住宅     住宅,店舗        住宅
# koji_building_structure         W         W         W         W         W
#
#                                15      16        17        18        19
# data_id                        15      16        17        18        19
# bukken_type                  1202    1202      1302      1302      1202
# bukken_type_label          kodate  kodate   mansion   mansion    kodate
# 2023_koji_price           98000.0    <NA>   55000.0   55000.0   23000.0
# 2022_koji_price           72500.0    <NA>   55000.0   55000.0   23500.0
# 2021_koji_price           68500.0    <NA>   55100.0   55100.0   23700.0
# 2020_koji_price           65800.0    <NA>   55200.0   55200.0   23900.0
# 2019_koji_price           61500.0    <NA>   55300.0   55300.0   24100.0
# 2018_koji_price           59000.0    <NA>   55400.0   55400.0   24200.0
# 2023_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2022_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2021_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2020_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2019_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2018_koji_usage_code          1低専    <NA>      <NA>      <NA>      <NA>
# 2023_koji_distance_km    0.857521    <NA>  0.441589  0.443916  0.598062
# 2022_koji_distance_km    0.672115    <NA>   0.44159  0.443919  0.598064
# 2021_koji_distance_km    0.672115    <NA>   0.44159  0.443919  0.598064
# 2020_koji_distance_km    0.672115    <NA>   0.44159  0.443919  0.598064
# 2019_koji_distance_km    0.672105    <NA>  0.441601  0.443923  0.598055
# 2018_koji_distance_km    0.672105    <NA>  0.441601  0.443923  0.598055
# koji_usage_status              住宅    <NA>        住宅        住宅        住宅
# koji_building_structure        LS    <NA>         W         W         W
#                     count           mean            std    min      25%  \
# 2023_koji_price  111431.0  305162.806849  543207.095706  810.0  78000.0
# 2022_koji_price  111430.0  294269.929103  522591.249478  830.0  76500.0
# 2021_koji_price  111429.0  291288.724748  556981.076239  860.0  76200.0
# 2020_koji_price  111425.0   293854.64236  576297.355109  895.0  76600.0
# 2019_koji_price  111426.0  276253.539659  530414.866814  930.0  76000.0
# 2018_koji_price  111426.0  261391.269632  486148.201592  970.0  75300.0
#
#                       50%       75%         max
# 2023_koji_price  155000.0  314500.0  39500000.0
# 2022_koji_price  151000.0  303000.0  39100000.0
# 2021_koji_price  149000.0  298000.0  39900000.0
# 2020_koji_price  149000.0  297000.0  43300000.0
# 2019_koji_price  147000.0  289000.0  42600000.0
# 2018_koji_price  145000.0  279000.0  40600000.0
#                           count      mean       std       min       25%  \
# 2023_koji_distance_km  111431.0  0.414447  0.363566  0.000042  0.201588
# 2022_koji_distance_km  111430.0  0.414173  0.363015  0.000042  0.201817
# 2021_koji_distance_km  111429.0  0.414156   0.36335  0.000042  0.201715
# 2020_koji_distance_km  111425.0  0.414476  0.364181  0.000042  0.201715
# 2019_koji_distance_km  111426.0  0.414489  0.364519  0.000033  0.201704
# 2018_koji_distance_km  111426.0  0.414927  0.365528  0.000033  0.201784
#
#                             50%       75%       max
# 2023_koji_distance_km   0.32338  0.494531  2.999917
# 2022_koji_distance_km  0.323446  0.494001  2.999917
# 2021_koji_distance_km  0.323263  0.493869  2.999917
# 2020_koji_distance_km  0.323122  0.494019  2.999917
# 2019_koji_distance_km  0.322887   0.49339  2.999903
# 2018_koji_distance_km  0.323274  0.493902  2.999903
#                        count unique  top   freq
# 2023_koji_usage_code  108174     12  1低専  24643
# 2022_koji_usage_code  108171     12  1低専  24614
# 2021_koji_usage_code  108174     12  1低専  24563
# 2020_koji_usage_code  108160     12  1低専  24579
# 2019_koji_usage_code  108160     12  1低専  24547
# 2018_koji_usage_code  108150     12  1低専  24539
#                    count
# bukken_type_label
# mansion            59545
# kodate             52892

# %% [markdown]
# # 01_02_join_population_projection outputs
#
# Automated preview of deterministic pipeline outputs saved under `data/interim`. Update the `DATASETS` list if the step emits new files.

# %%
from pathlib import Path

import pandas as pd
from IPython.display import display

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 400)

NOTEBOOK_RELATIVE_PATH = Path("notebooks/data/interim/01_02_join_population_projection/preview.ipynb")
try:
    NOTEBOOK_PATH = Path(__file__).resolve()
except NameError:  # running interactively
    NOTEBOOK_PATH = (Path.cwd() / NOTEBOOK_RELATIVE_PATH).resolve()


def resolve_project_root(notebook_path: Path) -> Path:
    for candidate in notebook_path.parents:
        if (candidate / "data").exists() and (candidate / "src").exists():
            return candidate
    return notebook_path.parents[-1]


PROJECT_ROOT = resolve_project_root(NOTEBOOK_PATH)
DATASETS = [
    ("train", PROJECT_ROOT / "data" / "interim" / "01_02_join_population_projection" / "train.parquet"),
    ("test", PROJECT_ROOT / "data" / "interim" / "01_02_join_population_projection" / "test.parquet"),
]
HEAD_ROWS = 20
COLUMN_OVERVIEW_SAMPLE_SIZE = 5
COLUMN_OVERVIEW_CHUNK_SIZE = 200
COLUMN_OVERVIEW_RANDOM_SEED = 314159


def build_column_overview(
    df: pd.DataFrame,
    *,
    sample_size: int = COLUMN_OVERVIEW_SAMPLE_SIZE,
    random_state: int | None = COLUMN_OVERVIEW_RANDOM_SEED,
) -> pd.DataFrame:
    row_count = len(df)
    overview_records: list[dict[str, object]] = []
    sample_columns = [f"random_sample_{i + 1}" for i in range(sample_size)]
    for idx, column in enumerate(df.columns):
        series = df[column]
        not_null_count = int(series.notna().sum())
        not_null_rate = (not_null_count / row_count * 100) if row_count else 0.0
        min_value = series.min(skipna=True)
        max_value = series.max(skipna=True)
        non_null = series.dropna()
        sample_n = min(sample_size, len(non_null))
        samples_list: list[object] = []
        if sample_n > 0:
            seed = None if random_state is None else random_state + idx
            samples_list = non_null.sample(n=sample_n, random_state=seed, replace=False).tolist()
        record: dict[str, object] = {
            "column_name": column,
            "row_count": row_count,
            "not_null_count": not_null_count,
            "not_null_rate_pct": round(not_null_rate, 2),
            "min": min_value,
            "max": max_value,
        }
        for sample_idx, col_name in enumerate(sample_columns):
            record[col_name] = samples_list[sample_idx] if sample_idx < len(samples_list) else pd.NA
        overview_records.append(record)
    return pd.DataFrame(overview_records)


def display_column_overview(
    df: pd.DataFrame | None,
    label: str,
    *,
    sample_size: int = COLUMN_OVERVIEW_SAMPLE_SIZE,
    chunk_size: int = COLUMN_OVERVIEW_CHUNK_SIZE,
    random_state: int | None = COLUMN_OVERVIEW_RANDOM_SEED,
) -> None:
    print(f"\n--- {label}: カラムサマリー ---")
    if df is None:
        print("⚠️ DataFrame が None のためサマリーを表示できません。")
        return
    if df.shape[1] == 0:
        print("(列が存在しません)")
        return
    overview = build_column_overview(
        df=df,
        sample_size=sample_size,
        random_state=random_state,
    )
    if overview.empty:
        print("(列が存在しません)")
        return
    total_cols = overview.shape[0]
    print(f"{total_cols} columns")
    for start in range(0, total_cols, chunk_size):
        end = min(start + chunk_size, total_cols)
        print(f"columns {start + 1}-{end} / {total_cols}")
        display(overview.iloc[start:end])


def inspect_dataset(label: str, path: Path, head_rows: int = HEAD_ROWS) -> None:
    if not path.exists():
        print(f"⚠️ Missing file: {path}")
        return
    df = pd.read_parquet(path)
    print(f"\n=== {label} ===")
    print(f"path: {path.relative_to(PROJECT_ROOT)}")
    print(f"shape: {df.shape[0]} rows x {df.shape[1]} cols")
    dtype_info = df.dtypes.astype(str)
    print("dtypes (first 20 columns):")
    print(dtype_info.head(20))
    if len(dtype_info) > 20:
        print("... (truncated)")
    sample = df.head(head_rows)
    display(sample.T)
    display_column_overview(df, label=f"{label} dataset")

# %%
for label, path in DATASETS:
    inspect_dataset(label, path)
# Out:
# === train ===
# path: data/interim/01_02_join_population_projection/train.parquet
# shape: 363924 rows x 141 cols
# dtypes (first 20 columns):
# data_id                       int64
# target_ym                     int64
# money_room                    int64
# building_id                   int64
# building_status               int64
# building_create_date         string
# building_modify_date         string
# building_type                 int64
# building_name                string
# homes_building_name          string
# homes_building_name_ruby     string
# unit_count                  float64
# full_address                 string
# lon                         float64
# lat                         float64
# building_structure          float64
# total_floor_area            float64
# building_area               float64
# floor_count                 float64
# basement_floor_count        float64
# dtype: object
# ... (truncated)
#                                                                           0   \
# data_id                                                                    0
# target_ym                                                             201901
# money_room                                                          13980000
# building_id                                                           206271
# building_status                                                            1
# building_create_date                                     2014-06-27 21:09:41
# building_modify_date                                     2019-01-24 00:10:08
# building_type                                                              4
# building_name                                                           <NA>
# homes_building_name                                          桑名市東正和台7丁目10-11
# homes_building_name_ruby                                                <NA>
# unit_count                                                               NaN
# full_address                                              三重県桑名市東正和台7丁目10-11
# lon                                                               136.637467
# lat                                                                35.047688
# building_structure                                                       1.0
# total_floor_area                                                      106.82
# building_area                                                            NaN
# floor_count                                                              2.0
# basement_floor_count                                                     NaN
# year_built                                                          199204.0
# building_land_area                                                188.490005
# land_area_all                                                     188.490005
# unit_area_min                                                            NaN
# unit_area_max                                                            NaN
# building_land_chimoku                                                    1.0
# land_youto                                                               1.0
# land_toshi                                                               1.0
# land_chisei                                                              NaN
# land_area_kind                                                           1.0
# land_setback_flg                                                         NaN
# land_setback                                                             NaN
# land_kenpei                                                             50.0
# land_youseki                                                            80.0
# land_road_cond                                                           NaN
# land_seigen                                                             <NA>
# building_area_kind                                                       1.0
# management_form                                                          NaN
# management_association_flg                                               NaN
# reform_exterior                                                         <NA>
# reform_exterior_other                                                   外壁塗装
# reform_exterior_date                                                201807.0
# building_tag_id                                         210202/210301/210101
# unit_id                                                               262186
# unit_name                                                               <NA>
# room_floor                                                               NaN
# balcony_area                                                             NaN
# dwelling_unit_window_angle                                               NaN
# room_count                                                               4.0
# unit_area                                                             106.82
# floor_plan_code                                                        450.0
# reform_wet_area                                                      1/2/3/4
# reform_wet_area_other                                                   <NA>
# reform_wet_area_date                                                201807.0
# reform_interior                                                         <NA>
# reform_interior_other                                                  畳表替え
# reform_interior_date                                                201807.0
# renovation_date                                                         <NA>
# renovation_etc                                                          <NA>
# unit_tag_id                                      310501/220701/220601/230401
# bukken_id                                                             360840
# snapshot_create_date                                     2018-10-30 00:00:00
# new_date                                                 2018-10-30 00:00:00
# snapshot_modify_date                                     2019-01-22 13:20:11
# timelimit_date                                           2019-02-05 00:00:00
# bukken_type                                                             1202
# flg_investment                                                           NaN
# empty_number                                                             1.0
# empty_contents                                                          <NA>
# post1                                                                  511.0
# post2                                                                  932.0
# addr1_1                                                                   24
# addr1_2                                                                  205
# addr2_name                                                           東正和台7丁目
# addr3_name                                                              <NA>
# nl                                                               126159934.0
# el                                                               491905398.0
# rosen_name1                                                          三岐鉄道北勢線
# eki_name1                                                                 在良
# bus_stop1                                                               <NA>
# bus_time1                                                                NaN
# walk_distance1                                                        1840.0
# rosen_name2                                                             <NA>
# eki_name2                                                               <NA>
# bus_stop2                                                               <NA>
# bus_time2                                                                NaN
# walk_distance2                                                           NaN
# traffic_other                                        コミュニティバス「東正和台」停より約 500m
# snapshot_land_area                                                    188.49
# snapshot_land_shidou                                                     NaN
# land_shidou_a                                                            NaN
# land_shidou_b                                                            NaN
# land_mochibun_a                                                          NaN
# land_mochibun_b                                                          NaN
# house_area                                                            106.82
# flg_new                                                                  0.0
# house_kanrinin                                                           NaN
# room_kaisuu                                                              NaN
# snapshot_window_angle                                                    NaN
# madori_number_all                                                          4
# madori_kind_all                                                           50
# money_kyoueki                                                            NaN
# money_kyoueki_tax                                                        3.0
# money_rimawari_now                                                       NaN
# money_shuuzen                                                            NaN
# money_shuuzenkikin                                                       NaN
# money_sonota_str1                                                       <NA>
# money_sonota1                                                            NaN
# money_sonota_str2                                                       <NA>
# money_sonota2                                                            NaN
# money_sonota_str3                                                       <NA>
# money_sonota3                                                            NaN
# parking_money                                                            0.0
# parking_money_tax                                                        NaN
# parking_kubun                                                            1.0
# parking_distance                                                         NaN
# parking_number                                                           2.0
# parking_memo                                                            <NA>
# genkyo_code                                                              2.0
# usable_status                                                              1
# usable_date                                                              NaN
# school_ele_name                                                        桑部小学校
# school_ele_distance                                                   2000.0
# school_jun_name                                                        正和中学校
# school_jun_distance                                                   2000.0
# convenience_distance                                                     NaN
# super_distance                                                           NaN
# hospital_distance                                                        NaN
# park_distance                                                            NaN
# drugstore_distance                                                       NaN
# bank_distance                                                            NaN
# shopping_street_distance                                                 NaN
# est_other_name                                                          <NA>
# est_other_distance                                                       NaN
# statuses                    210101/220701/220601/230401/310501/210301/210202
# parking_keiyaku                                                          NaN
# mesh_id_1km                                                         52364550
# mesh_population_2025                                               3682.9554
# mesh_population_2035                                               3638.1363
# mesh_population_2045                                               3429.8858
# mesh_population_2055                                               3102.9278
#
#                                                                            1   \
# data_id                                                                     1
# target_ym                                                              201901
# money_room                                                           24480000
# building_id                                                             83315
# building_status                                                             1
# building_create_date                                      2014-06-27 21:09:43
# building_modify_date                                      2019-04-03 00:10:08
# building_type                                                               4
# building_name                                                            <NA>
# homes_building_name                                                 桑名市松ノ木5丁目
# homes_building_name_ruby                                                 <NA>
# unit_count                                                                1.0
# full_address                                                 三重県桑名市松ノ木5丁目14-8
# lon                                                                136.639936
# lat                                                                 35.074625
# building_structure                                                       10.0
# total_floor_area                                                          NaN
# building_area                                                             NaN
# floor_count                                                               2.0
# basement_floor_count                                                      NaN
# year_built                                                           198108.0
# building_land_area                                                 290.519989
# land_area_all                                                             NaN
# unit_area_min                                                             NaN
# unit_area_max                                                             NaN
# building_land_chimoku                                                     NaN
# land_youto                                                                1.0
# land_toshi                                                                1.0
# land_chisei                                                               1.0
# land_area_kind                                                            2.0
# land_setback_flg                                                          1.0
# land_setback                                                              1.2
# land_kenpei                                                              50.0
# land_youseki                                                             80.0
# land_road_cond                                                            1.0
# land_seigen                                                              <NA>
# building_area_kind                                                        NaN
# management_form                                                           NaN
# management_association_flg                                                NaN
# reform_exterior                                                             2
# reform_exterior_other                                                    外壁塗装
# reform_exterior_date                                                 201706.0
# building_tag_id                                   330501/210301/210101/210201
# unit_id                                                                 35726
# unit_name                                                                <NA>
# room_floor                                                                NaN
# balcony_area                                                              NaN
# dwelling_unit_window_angle                                                5.0
# room_count                                                                4.0
# unit_area                                                          134.039993
# floor_plan_code                                                         450.0
# reform_wet_area                                                       1/2/3/4
# reform_wet_area_other                           キッチン・ユニットバス・洗面化粧台コーティング/トイレ新品
# reform_wet_area_date                                                 201706.0
# reform_interior                                                           2/4
# reform_interior_other                                                    <NA>
# reform_interior_date                                                 201706.0
# renovation_date                                                    2017-06-01
# renovation_etc              外装外壁塗装 内装システムキッチン新品/お風呂新品/洗面台新品/トイレ新品/フローリング上張...
# unit_tag_id                 260201/260301/220801/230601/260101/230101/2203...
# bukken_id                                                              267022
# snapshot_create_date                                      2018-10-30 00:00:00
# new_date                                                  2018-10-30 00:00:00
# snapshot_modify_date                                      2019-01-30 15:15:49
# timelimit_date                                            2019-02-13 00:00:00
# bukken_type                                                              1202
# flg_investment                                                            NaN
# empty_number                                                              NaN
# empty_contents                                                           <NA>
# post1                                                                   511.0
# post2                                                                   902.0
# addr1_1                                                                    24
# addr1_2                                                                   205
# addr2_name                                                             松ノ木5丁目
# addr3_name                                                               <NA>
# nl                                                                126256831.0
# el                                                                491914000.0
# rosen_name1                                                           三岐鉄道北勢線
# eki_name1                                                                  星川
# bus_stop1                                                                <NA>
# bus_time1                                                                 NaN
# walk_distance1                                                         1920.0
# rosen_name2                                                              <NA>
# eki_name2                                                                <NA>
# bus_stop2                                                                <NA>
# bus_time2                                                                 NaN
# walk_distance2                                                            NaN
# traffic_other                                          コミュニティバス「法務局前」停より約400m
# snapshot_land_area                                                     290.52
# snapshot_land_shidou                                                      NaN
# land_shidou_a                                                             NaN
# land_shidou_b                                                             NaN
# land_mochibun_a                                                           NaN
# land_mochibun_b                                                           NaN
# house_area                                                             134.04
# flg_new                                                                   0.0
# house_kanrinin                                                            NaN
# room_kaisuu                                                               NaN
# snapshot_window_angle                                                     NaN
# madori_number_all                                                           4
# madori_kind_all                                                            50
# money_kyoueki                                                             NaN
# money_kyoueki_tax                                                         3.0
# money_rimawari_now                                                        NaN
# money_shuuzen                                                             NaN
# money_shuuzenkikin                                                        NaN
# money_sonota_str1                                                        <NA>
# money_sonota1                                                             NaN
# money_sonota_str2                                                        <NA>
# money_sonota2                                                             NaN
# money_sonota_str3                                                        <NA>
# money_sonota3                                                             NaN
# parking_money                                                             0.0
# parking_money_tax                                                         NaN
# parking_kubun                                                             1.0
# parking_distance                                                          NaN
# parking_number                                                            3.0
# parking_memo                                                             <NA>
# genkyo_code                                                               2.0
# usable_status                                                               1
# usable_date                                                               NaN
# school_ele_name                                                       大山田南小学校
# school_ele_distance                                                     350.0
# school_jun_name                                                         陵成中学校
# school_jun_distance                                                    1100.0
# convenience_distance                                                      NaN
# super_distance                                                            NaN
# hospital_distance                                                         NaN
# park_distance                                                             NaN
# drugstore_distance                                                        NaN
# bank_distance                                                             NaN
# shopping_street_distance                                                  NaN
# est_other_name                                                           <NA>
# est_other_distance                                                        NaN
# statuses                    210101/220701/220601/220801/230601/250201/2103...
# parking_keiyaku                                                           NaN
# mesh_id_1km                                                          52364581
# mesh_population_2025                                                3054.8402
# mesh_population_2035                                                2985.6286
# mesh_population_2045                                                2878.4524
# mesh_population_2055                                                2723.2881
#
#                                                                            2   \
# data_id                                                                     2
# target_ym                                                              201901
# money_room                                                           24480000
# building_id                                                            140201
# building_status                                                             1
# building_create_date                                      2014-06-27 21:09:43
# building_modify_date                                      2020-06-06 00:10:11
# building_type                                                               4
# building_name                                                            <NA>
# homes_building_name                                                 桑名市松ノ木七丁目
# homes_building_name_ruby                                                 <NA>
# unit_count                                                                1.0
# full_address                                                三重県桑名市松ノ木7丁目16-10
# lon                                                                136.644708
# lat                                                                 35.072248
# building_structure                                                        1.0
# total_floor_area                                                          NaN
# building_area                                                             NaN
# floor_count                                                               2.0
# basement_floor_count                                                      NaN
# year_built                                                           199506.0
# building_land_area                                                 235.649994
# land_area_all                                                             NaN
# unit_area_min                                                             NaN
# unit_area_max                                                             NaN
# building_land_chimoku                                                     NaN
# land_youto                                                                1.0
# land_toshi                                                                1.0
# land_chisei                                                               1.0
# land_area_kind                                                            2.0
# land_setback_flg                                                          1.0
# land_setback                                                              1.2
# land_kenpei                                                              50.0
# land_youseki                                                             80.0
# land_road_cond                                                            2.0
# land_seigen                                                              <NA>
# building_area_kind                                                        NaN
# management_form                                                           NaN
# management_association_flg                                                NaN
# reform_exterior                                                             2
# reform_exterior_other                                                    外壁塗装
# reform_exterior_date                                                 201804.0
# building_tag_id                     210201/330501/334101/210101/210301/340301
# unit_id                                                                116820
# unit_name                                                                <NA>
# room_floor                                                                NaN
# balcony_area                                                              NaN
# dwelling_unit_window_angle                                                5.0
# room_count                                                                4.0
# unit_area                                                          114.589996
# floor_plan_code                                                         450.0
# reform_wet_area                                                       1/2/3/4
# reform_wet_area_other                           キッチン・ユニットバス・洗面化粧台コーティング/トイレ新品
# reform_wet_area_date                                                 201804.0
# reform_interior                                                           2/4
# reform_interior_other                                                    <NA>
# reform_interior_date                                                 201804.0
# renovation_date                                                    2018-04-01
# renovation_etc              外装外壁塗装 内装システムキッチン新品/お風呂新品/洗面台新品/トイレ新品/フローリング上張...
# unit_tag_id                 260201/260301/220801/230601/260101/230101/2203...
# bukken_id                                                              194544
# snapshot_create_date                                      2018-10-30 00:00:00
# new_date                                                  2018-10-30 00:00:00
# snapshot_modify_date                                      2019-01-30 15:15:49
# timelimit_date                                            2019-02-13 00:00:00
# bukken_type                                                              1202
# flg_investment                                                            NaN
# empty_number                                                              1.0
# empty_contents                                                           <NA>
# post1                                                                   511.0
# post2                                                                   902.0
# addr1_1                                                                    24
# addr1_2                                                                   205
# addr2_name                                                             松ノ木7丁目
# addr3_name                                                               <NA>
# nl                                                                126248373.0
# el                                                                491931000.0
# rosen_name1                                                           三岐鉄道北勢線
# eki_name1                                                                 蓮花寺
# bus_stop1                                                                <NA>
# bus_time1                                                                 NaN
# walk_distance1                                                         2000.0
# rosen_name2                                                              <NA>
# eki_name2                                                                <NA>
# bus_stop2                                                                <NA>
# bus_time2                                                                 NaN
# walk_distance2                                                            NaN
# traffic_other                                          コミュニティバス「松ノ木南」停より約350m
# snapshot_land_area                                                     235.65
# snapshot_land_shidou                                                      NaN
# land_shidou_a                                                             NaN
# land_shidou_b                                                             NaN
# land_mochibun_a                                                           NaN
# land_mochibun_b                                                           NaN
# house_area                                                             114.59
# flg_new                                                                   0.0
# house_kanrinin                                                            NaN
# room_kaisuu                                                               NaN
# snapshot_window_angle                                                     NaN
# madori_number_all                                                           4
# madori_kind_all                                                            50
# money_kyoueki                                                             NaN
# money_kyoueki_tax                                                         3.0
# money_rimawari_now                                                        NaN
# money_shuuzen                                                             NaN
# money_shuuzenkikin                                                        NaN
# money_sonota_str1                                                        <NA>
# money_sonota1                                                             NaN
# money_sonota_str2                                                        <NA>
# money_sonota2                                                             NaN
# money_sonota_str3                                                        <NA>
# money_sonota3                                                             NaN
# parking_money                                                             0.0
# parking_money_tax                                                         NaN
# parking_kubun                                                             1.0
# parking_distance                                                          NaN
# parking_number                                                            2.0
# parking_memo                                                             <NA>
# genkyo_code                                                               2.0
# usable_status                                                               1
# usable_date                                                               NaN
# school_ele_name                                                       大山田南小学校
# school_ele_distance                                                     850.0
# school_jun_name                                                         陵成中学校
# school_jun_distance                                                    1200.0
# convenience_distance                                                      NaN
# super_distance                                                            NaN
# hospital_distance                                                         NaN
# park_distance                                                             NaN
# drugstore_distance                                                        NaN
# bank_distance                                                             NaN
# shopping_street_distance                                                  NaN
# est_other_name                                                           <NA>
# est_other_distance                                                        NaN
# statuses                    210101/220701/220601/230401/220801/310501/2306...
# parking_keiyaku                                                           NaN
# mesh_id_1km                                                          52364581
# mesh_population_2025                                                3054.8402
# mesh_population_2035                                                2985.6286
# mesh_population_2045                                                2878.4524
# mesh_population_2055                                                2723.2881
#
#                                                                            3   \
# data_id                                                                     3
# target_ym                                                              201901
# money_room                                                           16300000
# building_id                                                            216551
# building_status                                                             1
# building_create_date                                      2014-06-27 19:24:11
# building_modify_date                                      2019-04-26 00:10:08
# building_type                                                               4
# building_name                                                            <NA>
# homes_building_name                                             中古戸建 知多市八幡字荒井
# homes_building_name_ruby                                                 <NA>
# unit_count                                                                NaN
# full_address                                                  愛知県知多市八幡荒井105-1
# lon                                                                136.875602
# lat                                                                 35.003174
# building_structure                                                        1.0
# total_floor_area                                                   106.809998
# building_area                                                             NaN
# floor_count                                                               2.0
# basement_floor_count                                                      NaN
# year_built                                                           200203.0
# building_land_area                                                 169.729996
# land_area_all                                                             NaN
# unit_area_min                                                             NaN
# unit_area_max                                                             NaN
# building_land_chimoku                                                     1.0
# land_youto                                                               12.0
# land_toshi                                                                1.0
# land_chisei                                                               NaN
# land_area_kind                                                            1.0
# land_setback_flg                                                          1.0
# land_setback                                                              NaN
# land_kenpei                                                              60.0
# land_youseki                                                            200.0
# land_road_cond                                                            NaN
# land_seigen                                                      準防火地域、文化財保護法
# building_area_kind                                                        NaN
# management_form                                                           NaN
# management_association_flg                                                NaN
# reform_exterior                                                          <NA>
# reform_exterior_other                                                    <NA>
# reform_exterior_date                                                      NaN
# building_tag_id                                          210101/210401/210301
# unit_id                                                                281648
# unit_name                                                                <NA>
# room_floor                                                                NaN
# balcony_area                                                              NaN
# dwelling_unit_window_angle                                                5.0
# room_count                                                                2.0
# unit_area                                                          106.809998
# floor_plan_code                                                         250.0
# reform_wet_area                                                          <NA>
# reform_wet_area_other                                                    <NA>
# reform_wet_area_date                                                      NaN
# reform_interior                                                          <NA>
# reform_interior_other                                                    <NA>
# reform_interior_date                                                      NaN
# renovation_date                                                          <NA>
# renovation_etc                                                           <NA>
# unit_tag_id                 220201/253501/253401/290401/290101/290901/2304...
# bukken_id                                                              345772
# snapshot_create_date                                      2018-12-01 00:00:00
# new_date                                                  2018-12-01 00:00:00
# snapshot_modify_date                                      2019-01-30 21:54:10
# timelimit_date                                            2019-02-13 00:00:00
# bukken_type                                                              1202
# flg_investment                                                            0.0
# empty_number                                                              0.0
# empty_contents                                                           <NA>
# post1                                                                   478.0
# post2                                                                     1.0
# addr1_1                                                                    23
# addr1_2                                                                   224
# addr2_name                                                              八幡字荒井
# addr3_name                                                               <NA>
# nl                                                                125999722.0
# el                                                                492762730.0
# rosen_name1                                                             名鉄常滑線
# eki_name1                                                                  寺本
# bus_stop1                                                                <NA>
# bus_time1                                                                 NaN
# walk_distance1                                                          480.0
# rosen_name2                                                             名鉄常滑線
# eki_name2                                                               尾張横須賀
# bus_stop2                                                                <NA>
# bus_time2                                                                 NaN
# walk_distance2                                                         1600.0
# traffic_other                                                            <NA>
# snapshot_land_area                                                     169.73
# snapshot_land_shidou                                                      NaN
# land_shidou_a                                                             NaN
# land_shidou_b                                                             NaN
# land_mochibun_a                                                           NaN
# land_mochibun_b                                                           NaN
# house_area                                                             106.81
# flg_new                                                                   0.0
# house_kanrinin                                                            NaN
# room_kaisuu                                                               NaN
# snapshot_window_angle                                                     NaN
# madori_number_all                                                           3
# madori_kind_all                                                            50
# money_kyoueki                                                             0.0
# money_kyoueki_tax                                                         2.0
# money_rimawari_now                                                        NaN
# money_shuuzen                                                             0.0
# money_shuuzenkikin                                                        NaN
# money_sonota_str1                                                        <NA>
# money_sonota1                                                             NaN
# money_sonota_str2                                                        <NA>
# money_sonota2                                                             NaN
# money_sonota_str3                                                        <NA>
# money_sonota3                                                             NaN
# parking_money                                                             0.0
# parking_money_tax                                                         NaN
# parking_kubun                                                             1.0
# parking_distance                                                          0.0
# parking_number                                                            3.0
# parking_memo                                                             <NA>
# genkyo_code                                                               1.0
# usable_status                                                               2
# usable_date                                                               NaN
# school_ele_name                                                         八幡小学校
# school_ele_distance                                                    1400.0
# school_jun_name                                                         八幡中学校
# school_jun_distance                                                    1400.0
# convenience_distance                                                      NaN
# super_distance                                                            NaN
# hospital_distance                                                         NaN
# park_distance                                                             NaN
# drugstore_distance                                                        NaN
# bank_distance                                                             NaN
# shopping_street_distance                                                  NaN
# est_other_name                                                           コンビニ
# est_other_distance                                                      300.0
# statuses                                   210101/290901/230401/210301/210401
# parking_keiyaku                                                           NaN
# mesh_id_1km                                                          52364700
# mesh_population_2025                                                 4594.915
# mesh_population_2035                                                4510.4234
# mesh_population_2045                                                 4325.702
# mesh_population_2055                                                4085.6396
#
#                                                                            4   \
# data_id                                                                     4
# target_ym                                                              201901
# money_room                                                           18800000
# building_id                                                            134968
# building_status                                                             1
# building_create_date                                      2014-06-27 19:24:12
# building_modify_date                                      2025-09-15 02:49:23
# building_type                                                               1
# building_name                                                        ロイヤル知多寺本
# homes_building_name                                                  ロイヤル知多寺本
# homes_building_name_ruby                                                 <NA>
# unit_count                                                               32.0
# full_address                                                  愛知県知多市八幡荒古後12-2
# lon                                                                136.875754
# ...
# rosen_name2                                                              <NA>
# eki_name2                                                                <NA>
# bus_stop2                                                                <NA>
# bus_time2                                                                 NaN
# walk_distance2                                                            NaN
# traffic_other                                                            <NA>
# snapshot_land_area                                                        NaN
# snapshot_land_shidou                                                      NaN
# land_shidou_a                                                             NaN
# land_shidou_b                                                             NaN
# land_mochibun_a                                                           NaN
# land_mochibun_b                                                           NaN
# house_area                                                                 67
# flg_new                                                                     0
# house_kanrinin                                                            3.0
# room_kaisuu                                                               7.0
# snapshot_window_angle                                                     NaN
# madori_number_all                                                           3
# madori_kind_all                                                            50
# money_kyoueki                                                          6500.0
# money_kyoueki_tax                                                         2.0
# money_rimawari_now                                                        NaN
# money_shuuzen                                                          6240.0
# money_shuuzenkikin                                                        NaN
# money_sonota_str1                                                        <NA>
# money_sonota1                                                             NaN
# money_sonota_str2                                                        <NA>
# money_sonota2                                                             NaN
# money_sonota_str3                                                        <NA>
# money_sonota3                                                             NaN
# parking_money                                                             NaN
# parking_money_tax                                                         NaN
# parking_kubun                                                             NaN
# parking_distance                                                          NaN
# parking_number                                                            NaN
# parking_memo                                                             <NA>
# genkyo_code                                                               2.0
# usable_status                                                               2
# usable_date                                                               NaN
# school_ele_name                                                     米原市立米原小学校
# school_ele_distance                                                     130.0
# school_jun_name                                                     米原市立米原中学校
# school_jun_distance                                                     400.0
# convenience_distance                                                    300.0
# super_distance                                                          750.0
# hospital_distance                                                         NaN
# park_distance                                                             NaN
# drugstore_distance                                                      350.0
# bank_distance                                                             NaN
# shopping_street_distance                                                  NaN
# est_other_name                                                           <NA>
# est_other_distance                                                        NaN
# statuses                    210101/340102/290401/230401/320101/210301/2102...
# parking_keiyaku                                                           NaN
# mesh_id_1km                                                          52367272
# mesh_population_2025                                                1948.1817
# mesh_population_2035                                                1879.0298
# mesh_population_2045                                                1755.7996
# mesh_population_2055                                                1582.3166
#
#                                                                           19
# data_id                                                                   19
# id                                                                        19
# target_ym                                                             202301
# building_id                                                           122307
# building_status                                                            1
# building_create_date                                     2014-06-27 21:11:26
# building_modify_date                                     2023-01-07 00:10:05
# building_type                                                              4
# building_name                                                           <NA>
# homes_building_name                                              米原市野一色 中古戸建
# homes_building_name_ruby                                  マイバラシノイッシキ チュウココダテ
# unit_count                                                               NaN
# full_address                                                 滋賀県米原市野一色1150-7
# lon                                                               136.352003
# lat                                                                35.386553
# building_structure                                                       1.0
# total_floor_area                                                       171.5
# building_area                                                            NaN
# floor_count                                                              2.0
# basement_floor_count                                                     NaN
# year_built                                                          201212.0
# building_land_area                                                205.130005
# land_area_all                                                            NaN
# unit_area_min                                                            NaN
# unit_area_max                                                            NaN
# building_land_chimoku                                                    1.0
# land_youto                                                              99.0
# land_toshi                                                               3.0
# land_chisei                                                              1.0
# land_area_kind                                                           1.0
# land_setback_flg                                                         NaN
# land_setback                                                             0.0
# land_kenpei                                                             70.0
# land_youseki                                                           200.0
# land_road_cond                                                           1.0
# land_seigen                                                             <NA>
# building_area_kind                                                       NaN
# management_form                                                          NaN
# management_association_flg                                               NaN
# reform_exterior                                                         <NA>
# reform_exterior_other                                                   <NA>
# reform_exterior_date                                                     NaN
# building_tag_id                                         210101/210202/210301
# unit_id                                                                 7509
# unit_name                                                               <NA>
# room_floor                                                               NaN
# balcony_area                                                             NaN
# dwelling_unit_window_angle                                               5.0
# room_count                                                               4.0
# unit_area                                                              171.5
# floor_plan_code                                                        450.0
# reform_wet_area                                                         <NA>
# reform_wet_area_other                                                   <NA>
# reform_wet_area_date                                                     NaN
# reform_interior                                                         <NA>
# reform_interior_other                                                   <NA>
# reform_interior_date                                                     NaN
# renovation_date                                                         <NA>
# renovation_etc                                                          <NA>
# unit_tag_id                                      223101/253501/253401/290801
# bukken_id                                                              82682
# snapshot_create_date                                     2022-09-26 00:00:00
# new_date                                                 2022-09-26 00:00:00
# snapshot_modify_date                                     2023-01-05 15:08:36
# timelimit_date                                           2023-01-19 00:00:00
# bukken_type                                                             1202
# flg_investment                                                           0.0
# empty_number                                                             NaN
# empty_contents                                                          <NA>
# post1                                                                  521.0
# post2                                                                  233.0
# addr1_1                                                                   25
# addr1_2                                                                  214
# addr2_name                                                               野一色
# addr3_name                                                              <NA>
# nl                                                               127380210.0
# el                                                               490877850.0
# rosen_name1                                                          JR東海道本線
# eki_name1                                                               近江長岡
# bus_stop1                                                               <NA>
# bus_time1                                                                NaN
# walk_distance1                                                        4320.0
# rosen_name2                                                             <NA>
# eki_name2                                                               <NA>
# bus_stop2                                                               <NA>
# bus_time2                                                                NaN
# walk_distance2                                                           NaN
# traffic_other                                                           <NA>
# snapshot_land_area                                                     205.0
# snapshot_land_shidou                                                     0.0
# land_shidou_a                                                            NaN
# land_shidou_b                                                            NaN
# land_mochibun_a                                                          NaN
# land_mochibun_b                                                          NaN
# house_area                                                               171
# flg_new                                                                    0
# house_kanrinin                                                           NaN
# room_kaisuu                                                              NaN
# snapshot_window_angle                                                    5.0
# madori_number_all                                                          4
# madori_kind_all                                                           50
# money_kyoueki                                                            NaN
# money_kyoueki_tax                                                        3.0
# money_rimawari_now                                                       NaN
# money_shuuzen                                                            0.0
# money_shuuzenkikin                                                       NaN
# money_sonota_str1                                                       <NA>
# money_sonota1                                                            NaN
# money_sonota_str2                                                       <NA>
# money_sonota2                                                            NaN
# money_sonota_str3                                                       <NA>
# money_sonota3                                                            NaN
# parking_money                                                            0.0
# parking_money_tax                                                        3.0
# parking_kubun                                                            1.0
# parking_distance                                                         NaN
# parking_number                                                           2.0
# parking_memo                                                            <NA>
# genkyo_code                                                              2.0
# usable_status                                                              2
# usable_date                                                              NaN
# school_ele_name                                                        大原小学校
# school_ele_distance                                                    587.0
# school_jun_name                                                        大東中学校
# school_jun_distance                                                   1636.0
# convenience_distance                                                   922.0
# super_distance                                                        1549.0
# hospital_distance                                                        NaN
# park_distance                                                            NaN
# drugstore_distance                                                    1428.0
# bank_distance                                                          679.0
# shopping_street_distance                                                 NaN
# est_other_name                                                  ホームプラザナフコ米原店
# est_other_distance                                                    1227.0
# statuses                    253501/210101/253401/223101/290801/210301/210202
# parking_keiyaku                                                          NaN
# mesh_id_1km                                                         53360268
# mesh_population_2025                                                979.6045
# mesh_population_2035                                                868.7637
# mesh_population_2045                                                813.3867
# mesh_population_2055                                                736.0981

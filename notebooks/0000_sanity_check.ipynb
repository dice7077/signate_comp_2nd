# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Users/takamiya/work/0000_repos/signate_comp_2nd/.venv/bin/python
# 3.10.19 (main, Oct  9 2025, 15:25:03) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
import lightgbm
print("lightgbm ok")
# Out:
# lightgbm ok

# %%
aaaa

# %% [markdown]
# ### Signate生データ件数メモ
# - train (`data/raw/signate/train.csv`): 363,924件（kodate: 165,310 / mansion: 198,614）
# - test (`data/raw/signate/test.csv`): 112,437件（kodate: 52,892 / mansion: 59,545）
# - 上記値は`data/metadata/signate_expected_counts.json`に固定し、各ステップの検証基準として利用する。
